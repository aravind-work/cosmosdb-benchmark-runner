# %%
import sys
# !{sys.executable} -m pip install seaborn --user
# !{sys.executable} -m pip install matplotlib --user
from IPython.display import clear_output

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %matplotlib inline

# %% [markdown]
# # This notebook visualizes the latency v4 SDKs in Direct vs Gateway on f4 Ubuntu Linux Azure VM

# %% [markdown]
# ## Point Read P99 Latency on 4 CPU cores VM (F4s)

# %%
point_read_f4s = pd.read_csv('notebooks/20200608-GW-Direct/f4/benchmark-results.csv', skipinitialspace=True)
sns.lineplot(x='ThreadCount', y ='P99(ms)', hue='OpName', data=(point_read_f4s[(point_read_f4s.ThreadCount < 75) & (point_read_f4s.ThreadCount > 1) & (point_read_f4s.OpName > 'PointRead')]))
